# %% [markdown]
# # Visualization

# %% [markdown]
# Loading data first.

# %%
model_dir = 'optlib5'
transfer = True

# %%
import pandas as pd
optlib_raw = pd.read_csv('storage/{}_transfer/log.csv'.format(model_dir) if transfer else 'storage/{}/log.csv'.format(model_dir) )
optlib_mean = optlib_raw.rreturn_mean
optlib_lower = optlib_mean - optlib_raw.rreturn_std
optlib_upper = optlib_mean + optlib_raw.rreturn_std

vanilla_raw = pd.read_csv('storage/vanilla1_transfer/log.csv' if transfer else 'storage/vanilla1/log.csv')
vanilla_mean = vanilla_raw.rreturn_mean
vanilla_lower = vanilla_mean - vanilla_raw.rreturn_std
vanilla_upper = vanilla_mean + vanilla_raw.rreturn_std

# %% [markdown]
# plot using Plotly

# %%
import plotly.graph_objects as go
import numpy as np
everyk = 200

cutoff = min(len(optlib_raw), len(vanilla_raw ))
x = list(optlib_raw['update'] if len(optlib_raw) >= cutoff else vanilla_raw['update'])
x = x[:cutoff][::everyk]

# Line 1
y1 = list(optlib_mean)[:cutoff][::everyk]
y1_upper = list(optlib_upper)[:cutoff][::everyk]
y1_lower = list(optlib_lower)[:cutoff][::everyk]

# Line 2
y2 = list(vanilla_mean)[:cutoff][::everyk]
y2_upper = list(vanilla_upper) [:cutoff][::everyk]
y2_lower = list(vanilla_lower) [:cutoff][::everyk]

x_rev = x[::-1]
y1_lower = y1_lower[::-1]
y2_lower = y2_lower[::-1]

# %%
fig = go.Figure()

fig.add_trace(go.Scatter(
    x=x+x_rev,
    y=y1_upper+y1_lower,
    fill='toself',
    fillcolor='rgba(0,100,80,0.2)',
    line_color='rgba(255,255,255,0)',
    showlegend=False,
    name='Optlib (ours)',
))
fig.add_trace(go.Scatter(
    x=x+x_rev,
    y=y2_upper+y2_lower,
    fill='toself',
    fillcolor='rgba(0,176,246,0.2)',
    line_color='rgba(255,255,255,0)',
    name='Vanilla baseline',
    showlegend=False,
))
# fig.add_trace(go.Scatter(
#     x=x+x_rev,
#     y=y3_upper+y3_lower,
#     fill='toself',
#     fillcolor='rgba(231,107,243,0.2)',
#     line_color='rgba(255,255,255,0)',
#     showlegend=False,
#     name='Ideal',Rename
# ))

fig.add_trace(go.Scatter(
    x=x, y=y2,
    line_color='rgb(0,176,246)',
    name='Vanilla baseline',
))

fig.add_trace(go.Scatter(
    x=x, y=y1,
    line_color='rgb(0,100,80)',
    name='Optlib (ours)',
))

# fig.add_trace(go.Scatter(
#     x=x, y=y3,
#     line_color='rgb(231,107,243)',
#     name='Ideal',
# ))


fig.update_yaxes(
        title_text = "Mean returns",
        title_standoff = 10)

fig.update_xaxes(
        title_text = "Updates",
        title_standoff = 10)


fig.update_traces(mode='lines')
fig.show()
# Out:
# <div>                            <div id="886aa706-1d4d-4135-873b-5035341687c8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("886aa706-1d4d-4135-873b-5035341687c8")) {                    Plotly.newPlot(                        "886aa706-1d4d-4135-873b-5035341687c8",                        [{"fill": "toself", "fillcolor": "rgba(0,100,80,0.2)", "line": {"color": "rgba(255,255,255,0)"}, "mode": "lines", "name": "Optlib (ours)", "showlegend": false, "type": "scatter", "x": [1, 201, 401, 601, 801, 1001, 1201, 1401, 1601, 1801, 2001, 2201, 2401, 2601, 2801, 3001, 3201, 3401, 3601, 3801, 4001, 4201, 4401, 4601, 4801, 5001, 5201, 5401, 5601, 5801, 6001, 6201, 6401, 6601, 6801, 7001, 7201, 7401, 7601, 7801, 8001, 8201, 8401, 8601, 8801, 9001, 9201, 9401, 9601, 9801, 10001, 10201, 10401, 10601, 10801, 11001, 11201, 11401, 11601, 11801, 12001, 12201, 12401, 12601, 12801, 13001, 13201, 13401, 13601, 13801, 14001, 14201, 14401, 14601, 14801, 15001, 15201, 15401, 15601, 15801, 16001, 16201, 16401, 16601, 16801, 17001, 17201, 17401, 17601, 17801, 18001, 18201, 18401, 18601, 18801, 19001, 19201, 19401, 19601, 19801, 20001, 20201, 20401, 20601, 20801, 21001, 21201, 21401, 21601, 21801, 22001, 22201, 22401, 22601, 22801, 23001, 23201, 23401, 23601, 23801, 24001, 24201, 24401, 24601, 24801, 25001, 25201, 25401, 25601, 25801, 26001, 26201, 26401, 26601, 26801, 27001, 27201, 27401, 27601, 27801, 28001, 28201, 28401, 28601, 28801, 29001, 29201, 29401, 29601, 29801, 30001, 30201, 30401, 30601, 30801, 31001, 31201, 31401, 31601, 31801, 32001, 32201, 32401, 32601, 32801, 33001, 33201, 33401, 33601, 33801, 34001, 34201, 34401, 34601, 34801, 35001, 35201, 35401, 35601, 35801, 36001, 36201, 36401, 36601, 36801, 37001, 37201, 37401, 37601, 37801, 38001, 38201, 38401, 38601, 38801, 39001, 39201, 39401, 39601, 39801, 40001, 40201, 40401, 40601, 40801, 41001, 41201, 41401, 41601, 41801, 42001, 42201, 42401, 42601, 42801, 43001, 43201, 43401, 43601, 43801, 44001, 44201, 44401, 44601, 44801, 45001, 45201, 45401, 45601, 45801, 46001, 46201, 46401, 46601, 46801, 47001, 47201, 47401, 47601, 47801, 48001, 48201, 48401, 48601, 48801, 49001, 49201, 49401, 49601, 49801, 49801, 49601, 49401, 49201, 49001, 48801, 48601, 48401, 48201, 48001, 47801, 47601, 47401, 47201, 47001, 46801, 46601, 46401, 46201, 46001, 45801, 45601, 45401, 45201, 45001, 44801, 44601, 44401, 44201, 44001, 43801, 43601, 43401, 43201, 43001, 42801, 42601, 42401, 42201, 42001, 41801, 41601, 41401, 41201, 41001, 40801, 40601, 40401, 40201, 40001, 39801, 39601, 39401, 39201, 39001, 38801, 38601, 38401, 38201, 38001, 37801, 37601, 37401, 37201, 37001, 36801, 36601, 36401, 36201, 36001, 35801, 35601, 35401, 35201, 35001, 34801, 34601, 34401, 34201, 34001, 33801, 33601, 33401, 33201, 33001, 32801, 32601, 32401, 32201, 32001, 31801, 31601, 31401, 31201, 31001, 30801, 30601, 30401, 30201, 30001, 29801, 29601, 29401, 29201, 29001, 28801, 28601, 28401, 28201, 28001, 27801, 27601, 27401, 27201, 27001, 26801, 26601, 26401, 26201, 26001, 25801, 25601, 25401, 25201, 25001, 24801, 24601, 24401, 24201, 24001, 23801, 23601, 23401, 23201, 23001, 22801, 22601, 22401, 22201, 22001, 21801, 21601, 21401, 21201, 21001, 20801, 20601, 20401, 20201, 20001, 19801, 19601, 19401, 19201, 19001, 18801, 18601, 18401, 18201, 18001, 17801, 17601, 17401, 17201, 17001, 16801, 16601, 16401, 16201, 16001, 15801, 15601, 15401, 15201, 15001, 14801, 14601, 14401, 14201, 14001, 13801, 13601, 13401, 13201, 13001, 12801, 12601, 12401, 12201, 12001, 11801, 11601, 11401, 11201, 11001, 10801, 10601, 10401, 10201, 10001, 9801, 9601, 9401, 9201, 9001, 8801, 8601, 8401, 8201, 8001, 7801, 7601, 7401, 7201, 7001, 6801, 6601, 6401, 6201, 6001, 5801, 5601, 5401, 5201, 5001, 4801, 4601, 4401, 4201, 4001, 3801, 3601,  ...
